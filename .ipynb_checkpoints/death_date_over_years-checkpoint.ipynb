# %%
import json
import pandas as pd

# %matplotlib inline
import matplotlib.pyplot as plt
import predict_death as pred

# %%
# cols = ['education_2003_revision','education_reporting_flag','sex','detail_age','detail_age_type',\
# 'marital_status','current_data_year','manner_of_death','358_cause_recode','39_cause_recode','race',\
# 'hispanic_originrace_recode']

cols = ['sex','detail_age','detail_age_type',\
'race']
filt = zip(['race','sex'],['01','M'])
years = range(2005,2016)
demographic = 'White Males'

death_dates_white_males = pred.death_date_over_years(years, cols, filt, demographic)
# Out:
# White Males will most likely die at 84.1496062992 years old.
# White Males will most likely die at 82.0393700787 years old.
# White Males will most likely die at 84.031496063 years old.
# White Males will most likely die at 85.0157480315 years old.
# White Males will most likely die at 84.031496063 years old.
# White Males will most likely die at 83.5826771654 years old.
# White Males will most likely die at 82.8582677165 years old.
# White Males will most likely die at 84.031496063 years old.
# White Males will most likely die at 82.8582677165 years old.
# White Males will most likely die at 85.0157480315 years old.
# White Males will most likely die at 84.6377952756 years old.

# %%
filt1 = zip(['race','sex'],['02','M'])
filt2 = zip(['race','sex'],['03','M'])
filt3 = zip(['race','sex'],['04','M'])
filt4 = zip(['race','sex'],['05','M'])

x1 = pred.predict_day_of_death(df, filt1, 'g', 'Black Males')
x2 = pred.predict_day_of_death(df, filt2, 'k', 'American Indian Males')
x1 = pred.predict_day_of_death(df, filt3, 'r', 'Chinese Males')
x2 = pred.predict_day_of_death(df, filt4, 'b', 'Japanese Males')

plt.text(50, -0.007, 'Age (yrs)', ha='center', va='center')
plt.text(-20, 0.02, 'Proportion of deaths', ha='center', va='center', rotation='vertical')

# %%
death_date_american_indian_male = death_date
