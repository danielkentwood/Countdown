# %%
import pandas as pd
import numpy as np

# %%
name_list = ['Cause of death',\
        'Cause of death Code',\
        'Ten-year Age Groups',\
        'Ten-year Age Groups Code',\
        'Gender',\
        'Gender Code',\
        'Hispanic Origin',\
        'Hispanic Origin Code',\
        'Race',\
        'Race Code',\
        'Deaths',\
        'Population',\
        'Crude Rate']

# %%
df = pd.read_table('./cache/data/Amador_county.txt', delim_whitespace=True,)
df = df.iloc[:,0:-2]
df.columns = name_list
is_end = df['Cause of death']=='---'
footer_start = np.where(is_end)[0][0]
df.drop(df.index[123:], inplace=True)
df.tail()
# Out:
#                                         Cause of death Cause of death Code  \
# 118        Urinary tract infection, site not specified               N39.0
# 119  Accidental poisoning by and exposure to narcot...                 X42
# 120  Accidental poisoning by and exposure to other ...                 X44
# 121         Intentional self-harm by handgun discharge                 X72
# 122         Intentional self-harm by handgun discharge                 X72
#
#     Ten-year Age Groups Ten-year Age Groups Code  Gender Gender Code  \
# 118           85+ years                      85+    Male           M
# 119         45-54 years                    45-54  Female           F
# 120         45-54 years                    45-54  Female           F
# 121         55-64 years                    55-64    Male           M
# 122         65-74 years                    65-74    Male           M
#
#             Hispanic Origin Hispanic Origin Code   Race Race Code  Deaths  \
# ...

# %%
df
# Out:
#                                         Cause of death Cause of death Code  \
# 0        Oesophagus, unspecified - Malignant neoplasms               C15.9
# 1        Oesophagus, unspecified - Malignant neoplasms               C15.9
# 2             Colon, unspecified - Malignant neoplasms               C18.9
# 3             Colon, unspecified - Malignant neoplasms               C18.9
# 4             Colon, unspecified - Malignant neoplasms               C18.9
# 5             Colon, unspecified - Malignant neoplasms               C18.9
# 6             Colon, unspecified - Malignant neoplasms               C18.9
# 7          Pancreas, unspecified - Malignant neoplasms               C25.9
# 8          Pancreas, unspecified - Malignant neoplasms               C25.9
# 9          Pancreas, unspecified - Malignant neoplasms               C25.9
# 10   Bronchus or lung, unspecified - Malignant neop...               C34.9
# ...
